# %%
from selenium import webdriver

# Chromeの起動
driver = webdriver.Chrome('/Users/yama/python/chromedriver')
# Out:
# <ipython-input-3-60b59e3b61df>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/yama/python/chromedriver')
